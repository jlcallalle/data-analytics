# %%
import pandas as pd

# %% [markdown]
# # 1. Creación de series y dataframes

# %%
a = [34, 78, 22, 13]

# %%
type(a)
# Out:
# list

# %%
mi_serie = pd.Series(a)

# %%
mi_serie
# Out:
# 0    34
# 1    78
# 2    22
# 3    13
# dtype: int64

# %%
type(mi_serie)
# Out:
# pandas.core.series.Series

# %%
data = {
    "calorias": [420, 380, 390],
    "duracion": [50, 40, 45]
}

# %%
type(data)
# Out:
# dict

# %%
mi_dataframe = pd.DataFrame(data)

# %%
mi_dataframe
# Out:
#    calorias  duracion
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df_prueba = pd.DataFrame()

# %%
df_prueba['edad'] = [12, 20, 14, 18]

# %%
df_prueba
# Out:
#    edad
# 0    12
# 1    20
# 2    14
# 3    18

# %%
df_prueba["peso"] = [56, 62, 74, 58]

# %%
df_prueba
# Out:
#    edad  peso
# 0    12    56
# 1    20    62
# 2    14    74
# 3    18    58

# %% [markdown]
# #2. Lectura de archivos csv y excel

# %% [markdown]
# Datasets: Alumnos matriculados en la Universidad Nacional de Ingeniería 2024-2 al 2025-1 [UNI]
#
# https://www.datosabiertos.gob.pe/dataset/alumnos-matriculados-en-la-universidad-nacional-de-ingenier%C3%ADa-2024-2-al-2025-1-uni

# %%
df_alumnos_uni = pd.read_csv("/content/Datos_abiertos_matriculas_2024_2_2025_1_0.csv", sep=',')

# %%
df_alumnos_uni
# Out:
#                                                   IDHASH COLEGIO_DEPA  \
# 0      04411BA6C8D0AC65DA30537077ED135906545B6ED5A828...         LIMA
# 1      B75E8796ADEEDB529C46058DA951BB17D1CCF2E2EB5B43...         LIMA
# 2      126C073D64AFB15EDA6003208FE900EFFA3D61C5464F84...        JUNIN
# 3      8AB39A3758E64121E67D0E7FD202C5A00B70AD544002AC...         LIMA
# 4      8E04C32C034E11F5523A88045E2ADE0F157D5BFB9C37EF...       CALLAO
# ...                                                  ...          ...
# 24877  73074978180611CC8B9D40523BF4C286A7194742DE75E7...         LIMA
# 24878  F7819AD164959E40AE05A76C7150AE8D25B0575894E69A...         LIMA
# 24879  D5A4E7716907039C1BC35B7ADFC7F15098854A25F2511A...         LIMA
# 24880  4F19DD51DA3C2869BFC04D11352E96D6FD942B71DF9F57...         LIMA
# 24881  BE93E75EA31505FD2E2585A38023D7973D80B8556FC097...         LIMA
#
#              COLEGIO_PROV             COLEGIO_DIST  ANIO  PERIODO  \
# ...

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_alumnos_uni_2 = pd.read_csv("/content/drive/MyDrive/data_curso_python/Datos_abiertos_matriculas_2024_2_2025_1_0.csv", sep=',')

# %%
df_alumnos_uni_2
# Out:
#                                                   IDHASH COLEGIO_DEPA  \
# 0      04411BA6C8D0AC65DA30537077ED135906545B6ED5A828...         LIMA
# 1      B75E8796ADEEDB529C46058DA951BB17D1CCF2E2EB5B43...         LIMA
# 2      126C073D64AFB15EDA6003208FE900EFFA3D61C5464F84...        JUNIN
# 3      8AB39A3758E64121E67D0E7FD202C5A00B70AD544002AC...         LIMA
# 4      8E04C32C034E11F5523A88045E2ADE0F157D5BFB9C37EF...       CALLAO
# ...                                                  ...          ...
# 24877  73074978180611CC8B9D40523BF4C286A7194742DE75E7...         LIMA
# 24878  F7819AD164959E40AE05A76C7150AE8D25B0575894E69A...         LIMA
# 24879  D5A4E7716907039C1BC35B7ADFC7F15098854A25F2511A...         LIMA
# 24880  4F19DD51DA3C2869BFC04D11352E96D6FD942B71DF9F57...         LIMA
# 24881  BE93E75EA31505FD2E2585A38023D7973D80B8556FC097...         LIMA
#
#              COLEGIO_PROV             COLEGIO_DIST  ANIO  PERIODO  \
# ...

# %%
df_alumnos_uni_2.head()
# Out:
#                                               IDHASH COLEGIO_DEPA  \
# 0  04411BA6C8D0AC65DA30537077ED135906545B6ED5A828...         LIMA
# 1  B75E8796ADEEDB529C46058DA951BB17D1CCF2E2EB5B43...         LIMA
# 2  126C073D64AFB15EDA6003208FE900EFFA3D61C5464F84...        JUNIN
# 3  8AB39A3758E64121E67D0E7FD202C5A00B70AD544002AC...         LIMA
# 4  8E04C32C034E11F5523A88045E2ADE0F157D5BFB9C37EF...       CALLAO
#
#          COLEGIO_PROV             COLEGIO_DIST  ANIO  PERIODO  TIPO_MATRICULA  \
# 0  LIMA METROPOLITANA  VILLA MARIA DEL TRIUNFO  2024        2  REINCORPORADOS
# 1  LIMA METROPOLITANA        VILLA EL SALVADOR  2024        2       REGULARES
# 2               TARMA       SAN PEDRO DE CAJAS  2024        2       REGULARES
# 3  LIMA METROPOLITANA              LA VICTORIA  2024        2       REGULARES
# 4              CALLAO               VENTANILLA  2024        2       REGULARES
#
#   DOMICILIO_DEPA      DOMICILIO_PROV           DOMICILIO_DIST  ...  \
# ...

# %%
df_alumnos_uni_2.shape
# Out:
# (24882, 22)

# %%
df_alumnos_uni_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24882 entries, 0 to 24881
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   IDHASH           24882 non-null  object
#  1   COLEGIO_DEPA     24882 non-null  object
#  2   COLEGIO_PROV     24882 non-null  object
#  3   COLEGIO_DIST     24882 non-null  object
#  4   ANIO             24882 non-null  int64
#  5   PERIODO          24882 non-null  int64
#  6   TIPO_MATRICULA   24882 non-null  object
#  7   DOMICILIO_DEPA   24882 non-null  object
#  8   DOMICILIO_PROV   24882 non-null  object
#  9   DOMICILIO_DIST   24882 non-null  object
#  10  ANIO_NACIMIENTO  24882 non-null  int64
#  11  NACIMIENTO_PAIS  24882 non-null  object
#  12  NACIMIENTO_DEPA  24882 non-null  object
#  13  NACIMIENTO_PROV  24882 non-null  object
#  14  NACIMIENTO_DIST  24882 non-null  object
#  15  SEXO             24882 non-null  object
# ...

# %%
df_diccionario = pd.read_excel("/content/drive/MyDrive/data_curso_python/DiccionarioDatos_matriculados.xlsx", header=3)

# %%
df_diccionario
# Out:
#           Columnas                                         Descripción  \
# 0            IDHASH  Identificador anónimo único para cada alumno, ...
# 1      COLEGIO_DEPA  Departamento donde se encuentra ubicado el col...
# 2      COLEGIO_PROV  Provincia donde se encuentra ubicado el colegi...
# 3      COLEGIO_DIST  Distrito donde se encuentra ubicado el colegio...
# 4              ANIO                  Año en que se matricula el alumno
# 5           PERIODO           Ciclo del año en que matricula el alumno
# 6    TIPO_MATRICULA  Tipo de matrícula para el alumno:  Regulares, ...
# 7    DOMICILIO_DEPA  Departamento donde se encuentra ubicado el dom...
# 8    DOMICILIO_PROV  Provincia donde se encuentra ubicado el domici...
# 9    DOMICILIO_DIST  Distrito donde se encuentra ubicado el domicil...
# 10  ANIO_NACIMIENTO                       Año de nacimiento del alumno
# 11  NACIMIENTO_PAIS           Nombre del pais de nacimiento del alumno
# ...

# %% [markdown]
# # 3. Guardar dataframes en archivos csv

# %%
df_prueba
# Out:
#    edad  peso
# 0    12    56
# 1    20    62
# 2    14    74
# 3    18    58

# %%
df_prueba.to_csv("/content/drive/MyDrive/data_curso_python/data_prueba_2026.csv", index=False)

# %% [markdown]
# #4. Selección de columnas

# %%
df_alumnos_uni_2[['IDHASH', 'COLEGIO_DEPA', 'COLEGIO_PROV', 'COLEGIO_DIST']]
# Out:
#                                                   IDHASH COLEGIO_DEPA  \
# 0      04411BA6C8D0AC65DA30537077ED135906545B6ED5A828...         LIMA
# 1      B75E8796ADEEDB529C46058DA951BB17D1CCF2E2EB5B43...         LIMA
# 2      126C073D64AFB15EDA6003208FE900EFFA3D61C5464F84...        JUNIN
# 3      8AB39A3758E64121E67D0E7FD202C5A00B70AD544002AC...         LIMA
# 4      8E04C32C034E11F5523A88045E2ADE0F157D5BFB9C37EF...       CALLAO
# ...                                                  ...          ...
# 24877  73074978180611CC8B9D40523BF4C286A7194742DE75E7...         LIMA
# 24878  F7819AD164959E40AE05A76C7150AE8D25B0575894E69A...         LIMA
# 24879  D5A4E7716907039C1BC35B7ADFC7F15098854A25F2511A...         LIMA
# 24880  4F19DD51DA3C2869BFC04D11352E96D6FD942B71DF9F57...         LIMA
# 24881  BE93E75EA31505FD2E2585A38023D7973D80B8556FC097...         LIMA
#
#              COLEGIO_PROV             COLEGIO_DIST
# 0      LIMA METROPOLITANA  VILLA MARIA DEL TRIUNFO
# ...

# %%
df_alumnos_uni_2.filter(['IDHASH', 'COLEGIO_DEPA', 'COLEGIO_PROV', 'COLEGIO_DIST', 'ANIO', 	'PERIODO'])
# Out:
#                                                   IDHASH COLEGIO_DEPA  \
# 0      04411BA6C8D0AC65DA30537077ED135906545B6ED5A828...         LIMA
# 1      B75E8796ADEEDB529C46058DA951BB17D1CCF2E2EB5B43...         LIMA
# 2      126C073D64AFB15EDA6003208FE900EFFA3D61C5464F84...        JUNIN
# 3      8AB39A3758E64121E67D0E7FD202C5A00B70AD544002AC...         LIMA
# 4      8E04C32C034E11F5523A88045E2ADE0F157D5BFB9C37EF...       CALLAO
# ...                                                  ...          ...
# 24877  73074978180611CC8B9D40523BF4C286A7194742DE75E7...         LIMA
# 24878  F7819AD164959E40AE05A76C7150AE8D25B0575894E69A...         LIMA
# 24879  D5A4E7716907039C1BC35B7ADFC7F15098854A25F2511A...         LIMA
# 24880  4F19DD51DA3C2869BFC04D11352E96D6FD942B71DF9F57...         LIMA
# 24881  BE93E75EA31505FD2E2585A38023D7973D80B8556FC097...         LIMA
#
#              COLEGIO_PROV             COLEGIO_DIST  ANIO  PERIODO
# ...

# %% [markdown]
# #5. Selección de filas

# %% [markdown]
# ## 5.1. Por valor

# %%
df_alumnos_uni_2.loc[df_alumnos_uni_2["COLEGIO_DEPA"].isin(["JUNIN", "PASCO"])]
# Out:
#                                                   IDHASH COLEGIO_DEPA  \
# 2      126C073D64AFB15EDA6003208FE900EFFA3D61C5464F84...        JUNIN
# 45     576C74C6B23B2EE98230A8D600188F352699AC5E78A209...        PASCO
# 54     7473ADC75FDEC0DABC9883BBEC82EC2F2BA06E020C3157...        JUNIN
# 96     574C9E0A35194EF6CAC99C73E56E81A9273518FB1345EA...        JUNIN
# 105    FA1BA835B4566E69E12B4B685B4BE2BF3AB8F49A2CD8A5...        JUNIN
# ...                                                  ...          ...
# 24763  26A2F66034BF32AAE988E396A2FF4A12DA2A618EB92AF6...        JUNIN
# 24765  80B893DC64DD02ED84BD0A68165C1148C5AE5CE1525D78...        JUNIN
# 24812  C9A1833C010F2AF6DD890D3D5ECE283E64BCC55C7F1D20...        JUNIN
# 24817  ACDFE47CBE84B0D7A36B9B5483DE723B13B5167C1302BB...        JUNIN
# 24863  C604DBD625F762FFB6D3D678DCC3D5785F4E8CAD0D0F40...        JUNIN
#
#       COLEGIO_PROV           COLEGIO_DIST  ANIO  PERIODO    TIPO_MATRICULA  \
# ...

# %%
df_alumnos_uni_2.loc[df_alumnos_uni_2["COLEGIO_DEPA"]=="JUNIN"]
# Out:
#                                                   IDHASH COLEGIO_DEPA  \
# 2      126C073D64AFB15EDA6003208FE900EFFA3D61C5464F84...        JUNIN
# 54     7473ADC75FDEC0DABC9883BBEC82EC2F2BA06E020C3157...        JUNIN
# 96     574C9E0A35194EF6CAC99C73E56E81A9273518FB1345EA...        JUNIN
# 105    FA1BA835B4566E69E12B4B685B4BE2BF3AB8F49A2CD8A5...        JUNIN
# 194    1ADA21B76E05EA036E1825CC7BD71B08F3E46B9A716A97...        JUNIN
# ...                                                  ...          ...
# 24763  26A2F66034BF32AAE988E396A2FF4A12DA2A618EB92AF6...        JUNIN
# 24765  80B893DC64DD02ED84BD0A68165C1148C5AE5CE1525D78...        JUNIN
# 24812  C9A1833C010F2AF6DD890D3D5ECE283E64BCC55C7F1D20...        JUNIN
# 24817  ACDFE47CBE84B0D7A36B9B5483DE723B13B5167C1302BB...        JUNIN
# 24863  C604DBD625F762FFB6D3D678DCC3D5785F4E8CAD0D0F40...        JUNIN
#
#       COLEGIO_PROV           COLEGIO_DIST  ANIO  PERIODO    TIPO_MATRICULA  \
# ...

# %% [markdown]
# ## 5.2. Por índice

# %%
df_alumnos_uni_2.iloc[0:25]
# Out:
#                                                IDHASH  COLEGIO_DEPA  \
# 0   04411BA6C8D0AC65DA30537077ED135906545B6ED5A828...          LIMA
# 1   B75E8796ADEEDB529C46058DA951BB17D1CCF2E2EB5B43...          LIMA
# 2   126C073D64AFB15EDA6003208FE900EFFA3D61C5464F84...         JUNIN
# 3   8AB39A3758E64121E67D0E7FD202C5A00B70AD544002AC...          LIMA
# 4   8E04C32C034E11F5523A88045E2ADE0F157D5BFB9C37EF...        CALLAO
# 5   5E7836E6726BEA39F0BAA2C77809A161ADDC5485BAE94C...          LIMA
# 6   E32002BF7325AE21736A48FBE7A673489718C2C6303DB9...          LIMA
# 7   DB188F93931E5BBA3E7A3D7700E1A0DD72633B5D6B9D14...          LIMA
# 8   CBD9D12FD085965FC409E05A8EA48142A39E59C9979A9D...        CALLAO
# 9   C4439C5CB18C984C4E12BCBBE5A21206A594230209F823...          LIMA
# 10  41DBAB0CF1CE8511E1D207C9C5D79A3781FE4C397FA3AE...  HUANCAVELICA
# 11  AF92AD6FA4B415EE46802721430D67C8953EB5B6AA6C8D...     NO INDICA
# 12  377785A55821F775AAB50D6EA79A8683B829C4142FE856...          LIMA
# ...

# %%
df_alumnos_uni_2.iloc[24500:]
# Out:
#                                                   IDHASH COLEGIO_DEPA  \
# 24500  05CF7356F173602A661C8488845F9BFE2E1CCED4B3E6B5...       TUMBES
# 24501  1F21FC599D3B111633EC946FF7DBA363BBD6478BAA76E0...         LIMA
# 24502  55CBE3E2AE7A4AD67F0D561D4B61296BD674BF5971FF6F...       ANCASH
# 24503  0B96FD09DBD27DD7BE979531983801947102C80D1AA529...        JUNIN
# 24504  FAF7C5931D6AD774E62E3407AF570E168EF396FE8F9189...       ANCASH
# ...                                                  ...          ...
# 24877  73074978180611CC8B9D40523BF4C286A7194742DE75E7...         LIMA
# 24878  F7819AD164959E40AE05A76C7150AE8D25B0575894E69A...         LIMA
# 24879  D5A4E7716907039C1BC35B7ADFC7F15098854A25F2511A...         LIMA
# 24880  4F19DD51DA3C2869BFC04D11352E96D6FD942B71DF9F57...         LIMA
# 24881  BE93E75EA31505FD2E2585A38023D7973D80B8556FC097...         LIMA
#
#              COLEGIO_PROV             COLEGIO_DIST  ANIO  PERIODO  \
# ...
